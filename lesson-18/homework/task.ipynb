# %% [markdown]
# Part 1: Reading Files

# %%
import pandas as pd

# %%
import sqlite3
with sqlite3.connect('data/chinook.db') as connection:
    df_employee = pd.read_sql(
        "SELECT * FROM employees",
        con=connection
    )

# %%
df_employee.head(10)
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %% [markdown]
# iris.json

# %%
df=pd.read_json('data/iris.json')
print("Shape of the dataset:", df.shape)
print("Column names:", df.columns.tolist())
# Out:
# Shape of the dataset: (150, 5)
# Column names: ['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species']

# %% [markdown]
# titanic.xlsx

# %%
df_titanic = pd.read_excel('data/titanic.xlsx', sheet_name='Sheet1')
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Flights parquet file

# %%
flights = pd.read_parquet('data/flights')
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %% [markdown]
# movie.csv

# %%
df_movie=pd.read_csv('data/movie.csv')
print(df_movie.sample(10))
# Out:
#                 color    director_name  num_critic_for_reviews  duration  \
# 3974            Color     Jack Sholder                   138.0      87.0
# 3995  Black and White   Stanley Kramer                    73.0     186.0
# 1553            Color      Tim Robbins                    70.0     132.0
# 2895            Color      Jesse Dylan                    34.0      93.0
# 3117            Color    Miguel Arteta                   212.0      87.0
# 551             Color      Ron Shelton                   132.0     116.0
# 193             Color   Alfonso Cuarón                   274.0     142.0
# 1653            Color  Martha Coolidge                    85.0     111.0
# 3692            Color        Jay Levey                    59.0     150.0
# 2389            Color   Rick Friedberg                    27.0      81.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 3974                     28.0                   217.0       Robert Rusler
# ...

# %% [markdown]
# Part 2: Exploring DataFrames

# %%
df=pd.read_json('data/iris.json')
new_columns = [column.lower() for column in df.columns]
new_columns
# Out:
# ['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'species']

# %% [markdown]
# From the titanic.xlsx DataFrame:

# %%
df_titanic = pd.read_excel('data/titanic.xlsx', sheet_name='Sheet1')
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
filter=df_titanic[df_titanic['Age']>30]
gender_counts = filter['Sex'].value_counts()
print(filter)
print(gender_counts)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_movie=pd.read_csv('data/movie.csv')
filtered_movie = df_movie[df_movie['duration'] > 120]
sorted_movie = filtered_movie.sort_values(by='director_facebook_likes', ascending=False)
sorted_movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 66    Color  Christopher Nolan                   645.0     152.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 120   Color  Christopher Nolan                   478.0     128.0
# 1222  Color  Christopher Nolan                   341.0     130.0
# 97    Color  Christopher Nolan                   642.0     148.0
# ...     ...                ...                     ...       ...
# 3357  Color                NaN                     9.0     142.0
# 3582  Color                NaN                    10.0     240.0
# 3799  Color                NaN                     2.0     199.0
# 4005  Color                NaN                     NaN     197.0
# 4031  Color                NaN                    10.0     173.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 66                    22000.0                 11000.0      Heath Ledger
# ...
